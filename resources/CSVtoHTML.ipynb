# %%
# import modules
import os
import pandas as me

# %%
# import data
city_weather = me.read_csv('city_weather_data.csv')
city_weather.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloud Cover  \
# 0  Kuala Terengganu   5.3302  103.1408     78.75        94           20
# 1       Yellowknife  62.4560 -114.3525     57.72        77           20
# 2          Buraidah  26.3260   43.9750    109.85         9           92
# 3   Yangi Marg`ilon  40.4272   71.7189     99.32        23            1
# 4             Vaini -21.2000 -175.2000     73.56        88           75
#
#    Wind Speed Country
# 0        5.99      MY
# 1        3.44      CA
# 2        4.47      SA
# 3        4.61      UZ
# 4       12.66      TO

# %%
# re-order columns
city_weather = city_weather[['City','Country','Max Temp','Humidity','Cloud Cover','Wind Speed','Lat','Lng']]
city_weather.head()
# Out:
#                City Country  Max Temp  Humidity  Cloud Cover  Wind Speed  \
# 0  Kuala Terengganu      MY     78.75        94           20        5.99
# 1       Yellowknife      CA     57.72        77           20        3.44
# 2          Buraidah      SA    109.85         9           92        4.47
# 3   Yangi Marg`ilon      UZ     99.32        23            1        4.61
# 4             Vaini      TO     73.56        88           75       12.66
#
#        Lat       Lng
# 0   5.3302  103.1408
# 1  62.4560 -114.3525
# 2  26.3260   43.9750
# 3  40.4272   71.7189
# 4 -21.2000 -175.2000

# %%
city_weather.to_html('weather_data.html', index=False, classes=['table', 'table-striped', 'table-hover'])
